# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import gc 

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df_file_diabets = pd.read_csv("../datasets/pima-indians-diabetes-database/diabetes.csv", sep=",")

# %%
df_file_diabets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
set_train = df_file_diabets[:385]
set_test = df_file_diabets[385:]

# %% [markdown]
# ***Criando uma árvore de decisão***

# %%
# método da árvore de decisão
def tree_decision(test):
    X = test.drop("Outcome",axis=1)
    y = test["Outcome"]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)
    
    lasso = linear_model.Lasso()
    dtree = DecisionTreeClassifier()
    dtree.fit(X_train,y_train)
    predictions = dtree.predict(X_test)
    
    print("Accuracy = {0} \n".format(accuracy_score(y_test, predictions)))
    print("Matrix de confusão")
    print(confusion_matrix(y_test, predictions))
    print('\n')
    print(classification_report(y_test, predictions))
    print('\n')
    
    cv_results = cross_validate(lasso, X, y, cv = 5, n_jobs = -1)
    print("Sorted")
    sorted(cv_results.keys())
    print("\n")
    print("mean test_score = {0}".format(cv_results["test_score"].mean()))
    print("\n")
    print("mean train_score = {0}".format(cv_results["train_score"].mean()))
    print("\n")
    print("mean score_time = {0}".format(cv_results["score_time"].mean()))
    print("\n")
    print("mean fit_time = {0}".format(cv_results["fit_time"].mean()))

# %%
set_train.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# rodando a árvore de decisão sem nenhuma limpeza de dados

tree_decision(set_train)
# Out:
# Accuracy = 0.646551724137931
#
# Matrix de confusão
# [[48 20]
#  [21 27]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.71      0.70        68
#            1       0.57      0.56      0.57        48
#
#    micro avg       0.65      0.65      0.65       116
#    macro avg       0.64      0.63      0.63       116
# weighted avg       0.65      0.65      0.65       116
#
#
#
# Sorted
#
#
# mean test_score = 0.16660621906035597
#
#
# mean train_score = 0.1830521467006587
#
#
# mean score_time = 0.0012026309967041015
#
#
# mean fit_time = 0.0030776500701904298
# /home/alison/.pyenv/versions/anaconda3-2019.03/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %% [markdown]
# ***Vou classificar os níveis de BMI de acordo com a tabela encontrada [aqui](http://ib.bioninja.com.au/standard-level/topic-2-molecular-biology/23-carbohydrates-and-lipids/body-mass-index.html)***
#
# *0 = abaixo do peso*
#
# *1 = peso normal*
#
# *2 = obeso nível 1*
#
# *3 = obeso nível 2*
#
# *4 = obeso nível 3*
#
# *NaN se for abaixo de 10 de BMI, por que nem um bebe pode nascer com um BMI abaixo disso*

# %%
def classificBMI(BMI):
    if BMI > 10 and BMI < 18.5:
        return 0
    elif BMI > 18.4 and BMI < 25:
        return 1
    elif BMI > 24.9 and BMI < 30:
        return 2
    elif BMI > 29.9 and BMI < 35:
        return 3
    elif BMI > 34.9 and BMI < 40:
        return 4
    elif BMI > 40:
        return 5
    else:
        return -10

# %%
set_train["classificBMI"] = set_train['BMI'].apply(classificBMI)
# Out:
# /home/alison/.pyenv/versions/anaconda3-2019.03/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
set_train.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  classificBMI
# 0                     0.627   50        1             3
# 1                     0.351   31        0             2
# 2                     0.672   32        1             1
# 3                     0.167   21        0             2
# 4                     2.288   33        1             5

# %%
# verificando correlação entre um par de dados e os valores de positivo e negativo de Outcome
sns.pairplot(set_train, diag_kind='kde', plot_kws={'alpha':0.2 }, hue="Outcome")
# Out:
# /home/alison/.pyenv/versions/anaconda3-2019.03/lib/python3.6/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/alison/.pyenv/versions/anaconda3-2019.03/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
# quantidade total de resultados positivos
set_train.query("Outcome == 1").any(axis=1).count()
# Out:
# 145

# %% [markdown]
# **De acordo com este [material](https://www.diabetes.org.br/publico/vivendo-com-diabetes/mitos-e-verdades) médico existem pessoas magras com diábetes, ou seja o sobrepeso é um fator de risco mas não é determinante.**

# %%
#  Comparar os resultdados positivos para diabetes para o indice de BMI
set_train.query("Outcome == 1")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 11            10      168             74              0        0  38.0
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# 15             7      100              0              0        0  30.0
# 16             0      118             84             47      230  45.8
# 17             7      107             74              0        0  29.6
# ...

# %% [markdown]
# ***Dados errados:***
# ***A tarefa é não excluir nenhum objeto***
#
# **1 - Verificar qual é a porcentagem de valores inconsistentes em cada atributo com zero**
#
# *É impossível ter pressão sanguínea 0, como esse dado é muito relativo a cada paciente vou preencher com a média*

# %%
set_train.query("Pregnancies == 0")["Pregnancies"].agg(['count'])
# Out:
# count    54
# Name: Pregnancies, dtype: int64

# %%
set_train["Pregnancies"].value_counts(normalize=True)
# Out:
# 1     0.161039
# 0     0.140260
# 2     0.129870
# 5     0.101299
# 3     0.090909
# 4     0.090909
# 7     0.080519
# 6     0.049351
# 8     0.044156
# 9     0.036364
# 10    0.028571
# 13    0.015584
# 12    0.012987
# 11    0.010390
# 15    0.002597
# 14    0.002597
# 17    0.002597
# Name: Pregnancies, dtype: float64

# %%
# Objetos com o valor 0 de Glicose
set_train.query("Glucose == 0")["Glucose"].agg(['count'])
# Out:
# count    4
# Name: Glucose, dtype: int64

# %%
set_train["Glucose"].value_counts(normalize=True)
# Out:
# 109    0.023377
# 100    0.023377
# 122    0.023377
# 106    0.023377
# 146    0.023377
# 105    0.020779
# 99     0.020779
# 112    0.018182
# 125    0.018182
# 111    0.018182
# 108    0.018182
# 129    0.018182
# 95     0.018182
# 103    0.015584
# 128    0.015584
# 107    0.015584
# 90     0.015584
# 102    0.015584
# 101    0.012987
# 115    0.012987
# 139    0.012987
# 126    0.012987
# 124    0.012987
# 119    0.012987
# 88     0.012987
# 114    0.012987
# 113    0.012987
# 96     0.012987
# 85     0.012987
# 87     0.012987
#          ...
# 145    0.002597
# 75     0.002597
# 62     0.002597
# 76     0.002597
# 61     0.002597
# 77     0.002597
# 153    0.002597
# 57     0.002597
# 154    0.002597
# 135    0.002597
# 44     0.002597
# 132    0.002597
# 170    0.002597
# 193    0.002597
# 182    0.002597
# 177    0.002597
# 168    0.002597
# 178    0.002597
# 167    0.002597
# 166    0.002597
# 164    0.002597
# 98     0.002597
# 86     0.002597
# 183    0.002597
# ...

# %%
# Objetos com o valor de pressão sanguinéa de 0
set_train.query("BloodPressure == 0")["BloodPressure"].agg(['count'])
# Out:
# count    17
# Name: BloodPressure, dtype: int64

# %%
set_train["BloodPressure"].value_counts(normalize=True)
# Out:
# 70     0.072727
# 74     0.062338
# 72     0.062338
# 68     0.059740
# 80     0.057143
# 64     0.057143
# 76     0.051948
# 66     0.049351
# 78     0.046753
# 60     0.044156
# 62     0.044156
# 0      0.044156
# 82     0.036364
# 84     0.033766
# 88     0.025974
# 86     0.025974
# 90     0.025974
# 58     0.023377
# 50     0.023377
# 92     0.015584
# 52     0.015584
# 56     0.015584
# 75     0.012987
# 48     0.010390
# 65     0.010390
# 85     0.010390
# 54     0.007792
# 108    0.005195
# 55     0.005195
# 30     0.005195
# 96     0.005195
# 110    0.005195
# 98     0.005195
# 46     0.002597
# 44     0.002597
# 40     0.002597
# 102    0.002597
# 104    0.002597
# 100    0.002597
# 95     0.002597
# 94     0.002597
# 122    0.002597
# Name: BloodPressure, dtype: float64

# %%
set_train.query("SkinThickness == 0")["SkinThickness"].agg(['count'])
# Out:
# count    114
# Name: SkinThickness, dtype: int64

# %%
set_train["SkinThickness"].value_counts(normalize=True)
# Out:
# 0     0.296104
# 32    0.036364
# 28    0.033766
# 30    0.033766
# 15    0.028571
# 33    0.028571
# 23    0.025974
# 37    0.025974
# 39    0.023377
# 18    0.023377
# 19    0.023377
# 35    0.023377
# 22    0.020779
# 26    0.020779
# 25    0.020779
# 31    0.020779
# 27    0.020779
# 20    0.020779
# 29    0.020779
# 41    0.018182
# 42    0.018182
# 40    0.015584
# 36    0.015584
# 21    0.015584
# 24    0.015584
# 16    0.012987
# 13    0.012987
# 34    0.012987
# 38    0.010390
# 43    0.010390
# 44    0.010390
# 17    0.010390
# 11    0.007792
# 12    0.007792
# 10    0.007792
# 14    0.007792
# 50    0.005195
# 45    0.005195
# 47    0.005195
# 54    0.005195
# 8     0.002597
# 7     0.002597
# 51    0.002597
# 56    0.002597
# 52    0.002597
# 46    0.002597
# 48    0.002597
# 60    0.002597
# Name: SkinThickness, dtype: float64

# %%
set_train.query("Insulin == 0")["Insulin"].agg(['count'])
# Out:
# count    187
# Name: Insulin, dtype: int64

# %%
set_train["Insulin"].value_counts(normalize=True)
# Out:
# 0      0.485714
# 94     0.015584
# 140    0.015584
# 130    0.012987
# 135    0.012987
# 110    0.010390
# 100    0.007792
# 105    0.007792
# 64     0.007792
# 120    0.007792
# 325    0.007792
# 48     0.007792
# 168    0.007792
# 175    0.007792
# 83     0.007792
# 92     0.005195
# 114    0.005195
# 148    0.005195
# 155    0.005195
# 156    0.005195
# 99     0.005195
# 96     0.005195
# 82     0.005195
# 88     0.005195
# 182    0.005195
# 23     0.005195
# 36     0.005195
# 37     0.005195
# 40     0.005195
# 45     0.005195
#          ...
# 207    0.002597
# 205    0.002597
# 158    0.002597
# 160    0.002597
# 167    0.002597
# 204    0.002597
# 171    0.002597
# 180    0.002597
# 485    0.002597
# 125    0.002597
# 84     0.002597
# 122    0.002597
# 87     0.002597
# 258    0.002597
# 89     0.002597
# 90     0.002597
# 255    0.002597
# 249    0.002597
# 245    0.002597
# 240    0.002597
# 235    0.002597
# 744    0.002597
# 108    0.002597
# 231    0.002597
# ...

# %%
set_train.query("BMI == 0")["BMI"].agg(['count'])
# Out:
# count    6
# Name: BMI, dtype: int64

# %%
set_train["BMI"].value_counts(normalize=True)
# Out:
# 31.2    0.023377
# 31.6    0.018182
# 33.3    0.015584
# 29.7    0.015584
# 0.0     0.015584
# 28.7    0.012987
# 34.0    0.012987
# 34.2    0.012987
# 32.0    0.012987
# 30.8    0.012987
# 30.5    0.012987
# 33.6    0.010390
# 37.7    0.010390
# 27.6    0.010390
# 35.8    0.010390
# 32.9    0.010390
# 25.2    0.010390
# 32.8    0.010390
# 36.6    0.010390
# 30.1    0.010390
# 30.0    0.010390
# 35.9    0.010390
# 32.4    0.010390
# 29.0    0.010390
# 33.7    0.007792
# 25.4    0.007792
# 37.2    0.007792
# 30.4    0.007792
# 26.8    0.007792
# 35.4    0.007792
#           ...
# 26.2    0.002597
# 33.9    0.002597
# 25.8    0.002597
# 39.6    0.002597
# 28.4    0.002597
# 49.7    0.002597
# 29.3    0.002597
# 27.2    0.002597
# 34.4    0.002597
# 39.7    0.002597
# 23.8    0.002597
# 40.2    0.002597
# 44.2    0.002597
# 23.1    0.002597
# 67.1    0.002597
# 27.8    0.002597
# 31.9    0.002597
# 24.2    0.002597
# 42.2    0.002597
# 29.9    0.002597
# 25.3    0.002597
# ...

# %%
set_train.query("DiabetesPedigreeFunction == 0")["DiabetesPedigreeFunction"].agg(['count'])
# Out:
# count    0
# Name: DiabetesPedigreeFunction, dtype: int64

# %%
set_train.query("Age == 0")["Age"].agg(['count'])
# Out:
# count    0
# Name: Age, dtype: int64

# %%
set_train.query("classificBMI == -10")["classificBMI"].agg(['count'])
# Out:
# count    7
# Name: classificBMI, dtype: int64

# %%
set_train["classificBMI"].value_counts(normalize=True)
# Out:
#  3     0.301299
#  2     0.218182
#  4     0.192208
#  1     0.135065
#  5     0.132468
# -10    0.018182
#  0     0.002597
# Name: classificBMI, dtype: float64

# %% [markdown]
# ***Vou começar a colocar a média nos valores que fazem sentido***

# %%
set_train.plot.hist()

# %%
# Separando os pacientes saudáveis com missing value
set_train_healthy_index = set_train.query("Outcome == 0 and Insulin == 0").index

# separando os objetos que não tem missing value em Insulin e que pertencem a pacientes saudáveis
set_train_notInsulin_zero_negative = set_train.query("Outcome == 0 and Insulin > 0")

# tirando a média dos valores válidos e colocando no objetos que tem missing value e são dos pacientes saudáveis 
set_train.iloc[set_train_healthy_index, 4] = set_train_notInsulin_zero_negative["Insulin"].mean()
# Out:
# /home/alison/.pyenv/versions/anaconda3-2019.03/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Separando os pacientes não saudáveis com missing value
set_train_notHealthy_index = set_train.query("Outcome == 1 and Insulin == 0").index

# separando os objetos que não tem missing value em Insulin e que pertencem a pacientes não saudáveis
set_train_notInsulin_zero_positive = set_train.query("Outcome == 1 and Insulin > 0")

# tirando a média dos valores válidos e colocando no objetos que tem missing value e são de pacientes não saudáveis
set_train.iloc[set_train_notHealthy_index, 4] = set_train_notInsulin_zero_positive["Insulin"].mean()

# %%
set_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6      148             72             35  204.666667  33.6
# 1              1       85             66             29  129.047619  26.6
# 2              8      183             64              0  204.666667  23.3
# 3              1       89             66             23   94.000000  28.1
# 4              0      137             40             35  168.000000  43.1
# 5              5      116             74              0  129.047619  25.6
# 6              3       78             50             32   88.000000  31.0
# 7             10      115              0              0  129.047619  35.3
# 8              2      197             70             45  543.000000  30.5
# 9              8      125             96              0  204.666667   0.0
# 10             4      110             92              0  129.047619  37.6
# 11            10      168             74              0  204.666667  38.0
# ...

# %%
#set_train.query("Outcome == 0")

# %%
#df_file_diabets.iloc[healthy_index, 4] = healthy["Insulin"].mean()

# %%
#not_healthy = df_file_diabets.query("Outcome == 1")

# %%
#not_healthy["Insulin"].describe()

# %%
gc.collect()
# Out:
# 806

# %%
#not_healthy_insulin_zero_index = not_healthy.query("Insulin == 0").index
#not_healthy_insulin_notZero = not_healthy.query("Insulin > 0")

# %%
#not_healthy_insulin_notZero

# %%
#set_train.iloc[not_healthy_insulin_zero_index, 4] = not_healthy_insulin_notZero["Insulin"].mean()

# %%
#df_file_diabets.........

# %%
#healthy_index = df_file_diabets.query("Outcome == 0 and Insulin == 0").index

# %%
#df_file_diabets.iloc[healthy_index, 4] = healthy["Insulin"].mean()

# %%
#df_file_diabets

# %%
#def mean_insulin_patient_positive(list_parameters):
#    print(list_parameters)
#    if list_parameters[0].get == 1:
#        if list_parameters[1] == 0:
#            return 100
#        else:
#            list_parameters[1]
#    return list_parameters[1]

# %%
set_train["Insulin"].plot.hist()

# %%
tree_decision(set_test)
# Out:
# Accuracy = 0.782608695652174
#
# Matrix de confusão
# [[72 12]
#  [13 18]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85        84
#            1       0.60      0.58      0.59        31
#
#    micro avg       0.78      0.78      0.78       115
#    macro avg       0.72      0.72      0.72       115
# weighted avg       0.78      0.78      0.78       115
#
#
#
# Sorted
#
#
# mean test_score = 0.18021810766315366
#
#
# mean train_score = 0.2510105478687757
#
#
# mean score_time = 0.0017348289489746093
#
#
# mean fit_time = 0.0036227226257324217
# /home/alison/.pyenv/versions/anaconda3-2019.03/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
gc.collect()

# %% [markdown]
# ***Agora vou atacar o segundo atributo que mais tem valores inconsistentes, que é o SkinThickness***

# %%
# separando os objetos referentes a saúdavel e não saúdavel
heathy_atributes_all = df_file_diabets.query("Outcome == 1")
not_heathy_atributes_all = df_file_diabets.query("Outcome == 0")

# %%
# colocando a média de SkinThickness para as pessoas saúdaveis 

SkinThickness_healthy_index = df_file_diabets.query("SkinThickness == 0 and Outcome == 0").index

df_file_diabets.iloc[SkinThickness_healthy_index, 3] = heathy_atributes_all["SkinThickness"].mean()

df_file_diabets

# %%
# colocando a média de SkinThickness para pessoas não saúdaveis

SkinThickness_not_healthy_index = df_file_diabets.query("SkinThickness == 0 and Outcome ==1").index

df_file_diabets.iloc[SkinThickness_not_healthy_index, 3] = heathy_atributes_all["SkinThickness"].mean()

df_file_diabets

# %%
tree_decision(df_file_diabets)

# %%
sns.pairplot(df_file_diabets, diag_kind='kde', plot_kws={'alpha':0.2 }, hue="Outcome")

# %%
df_file_diabets.head()

# %%
df_file_diabets.drop("BMI", axis=1, inplace=True)

# %%
tree_decision(df_file_diabets)

# %%
df_file_diabets.drop("Pregnancies", axis=1, inplace=True)

# %%
tree_decision(df_file_diabets)
